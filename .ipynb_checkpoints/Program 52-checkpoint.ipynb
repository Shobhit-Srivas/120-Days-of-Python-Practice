# %% [markdown]
# # Problem 52: Write a functon to check if a string is an anagram.

# %%
print("=" * 60)
print("Q22. Write a function to check if a string is an anagram.")
print("=" * 60)

def is_anagram(str1, str2):
    return sorted(str1.lower()) == sorted(str2.lower())

str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

if is_anagram(str1, str2):
    print("\nThe strings are Anagrams.")
else:
    print("\nThe strings are not Anagrams.")
# Out:
# ============================================================
# Q22. Write a function to check if a string is an anagram.
# ============================================================
# Enter first string:  thie
# Enter second string:  lsdk
# The strings are not Anagrams.
