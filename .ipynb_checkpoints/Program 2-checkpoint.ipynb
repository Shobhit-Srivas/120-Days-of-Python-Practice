# %% [markdown]
# # Problem 2: Take user input and display it back to the user.

# %%
user_input = input("Enter something: ")

print("You entered:", user_input)
# Out:
# Enter something:  hello my
# You entered: hello my
