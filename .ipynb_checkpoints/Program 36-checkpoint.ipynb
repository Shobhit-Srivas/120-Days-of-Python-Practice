# %% [markdown]
# # Problem 36: Create a tuple and access its elements.

# %%
print("=" * 60)
print("Q6. Create a tuple and access its elements.")
print("=" * 60)

data = tuple(input("Enter tuple elements separated by spaces: ").split())

print("\nTuple Elements:")

for item in data:
    print(item)
# Out:
# ...
# Q6. Create a tuple and access its elements.
# ...
# Enter tuple elements separated by spaces:  1 2 3
# Tuple Elements:
# 1
# 2
# 3
