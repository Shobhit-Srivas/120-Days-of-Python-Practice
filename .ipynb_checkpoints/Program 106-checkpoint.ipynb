# %% [markdown]
# # Problem 106: Write a script that checks if all characters in a string are digits.

# %%
print("=" * 60)
print("Q36. Write a script that checks if all characters in a string are digits.")
print("=" * 60)

text = input("Enter a string: ")

if text.isdigit():
    print("\nAll Characters are Digits.")
else:
    print("\nThe String Contains Non-Digit Characters.")
# Out:
# ...
# Q36. Write a script that checks if all characters in a string are digits.
# ...
# Enter a string:  this
# The String Contains Non-Digit Characters.
