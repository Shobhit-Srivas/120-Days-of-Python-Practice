# %% [markdown]
# # Problem 35: Write a functon to reverse a list.

# %%
print("=" * 60)
print("Q5. Write a function to reverse a list.")
print("=" * 60)

def reverse_list(lst):
    return lst[::-1]

numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

print("\nReversed List:")
print(reverse_list(numbers))
# Out:
# ...
# Q5. Write a function to reverse a list.
# ...
# Enter numbers separated by spaces:  1 2 3
# Reversed List:
# [3, 2, 1]
