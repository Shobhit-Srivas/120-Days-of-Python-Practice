# %% [markdown]
# # Problem 49: Write a functon to remove all punctuaton from a string.

# %%
print("=" * 60)
print("Q19. Write a function to remove all punctuation from a string.")
print("=" * 60)

import string

def remove_punctuation(text):
    return "".join(ch for ch in text if ch not in string.punctuation)

text = input("Enter a string: ")

print("\nString after removing punctuation:")
print(remove_punctuation(text))
# Out:
# ============================================================
# Q19. Write a function to remove all punctuation from a string.
# ============================================================
# Enter a string:  string
# String after removing punctuation:
# string
