# %% [markdown]
# # Problem 82: Write a program to replace all spaces in a string with underscores.

# %%
print("=" * 60)
print("Q12. Write a program to replace all spaces in a string with underscores.")
print("=" * 60)

text = input("Enter a string: ")

result = text.replace(" ", "_")

print("\nModified String:")
print(result)
# Out:
# ...
# Q12. Write a program to replace all spaces in a string with underscores.
# ...
# Enter a string:  this is a
# Modified String:
# this_is_a
