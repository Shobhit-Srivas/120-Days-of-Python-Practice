# %% [markdown]
# # Problem 19: Write a program to calculate the sum of digits of a number.

# %%
print("=" * 60)
print("Q19. Write a program to calculate the sum of digits of a number.")
print("=" * 60)

num = input("Enter a number: ")

digit_sum = sum(int(digit) for digit in num)

print("\nSum of digits is:", digit_sum)
# Out:
# ...
# Q19. Write a program to calculate the sum of digits of a number.
# ...
# Enter a number:  25
# Sum of digits is: 7
