# %% [markdown]
# # Problem 27: Create a program to find the square root of a number.

# %%
import math

print("=" * 60)
print("Q27. Create a program to find the square root of a number.")
print("=" * 60)

num = float(input("Enter a number: "))

print("\nSquare root of", num, "is:", math.sqrt(num))
# Out:
# ...
# Q27. Create a program to find the square root of a number.
# ...
# Enter a number:  14
# Square root of 14.0 is: 3.7416573867739413
