# %% [markdown]
# # Problem 41: Write a program to sort a list in ascending order.

# %%
print("=" * 60)
print("Q11. Write a program to sort a list in ascending order.")
print("=" * 60)

numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

numbers.sort()

print("\nSorted List in Ascending Order:")
print(numbers)
# Out:
# ...
# Q11. Write a program to sort a list in ascending order.
# ...
# Enter numbers separated by spaces:  1 2 3
# Sorted List in Ascending Order:
# [1, 2, 3]
