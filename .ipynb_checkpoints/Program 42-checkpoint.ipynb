# %% [markdown]
# # Problem 42: Create a program to check if a key exists in a dictonary.

# %%
print("=" * 60)
print("Q12. Create a program to check if a key exists in a dictionary.")
print("=" * 60)

data = {"name": "Shobhit", "age": 21, "city": "Prayagraj"}

key = input("Enter key to search: ")

if key in data:
    print("\nKey exists in the dictionary.")
else:
    print("\nKey does not exist in the dictionary.")
# Out:
# ...
# Q12. Create a program to check if a key exists in a dictionary.
# ...
# Enter key to search:  name
# Key exists in the dictionary.
