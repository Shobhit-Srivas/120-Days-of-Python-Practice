# %% [markdown]
# # Problem 72: Create a program that removes all duplicate characters from a string.

# %%
print("=" * 60)
print("Q2. Create a program that removes all duplicate characters from a string.")
print("=" * 60)

text = input("Enter a string: ")

result = "".join(dict.fromkeys(text))

print("\nString after removing duplicates:")
print(result)
# Out:
# ...
# Q2. Create a program that removes all duplicate characters from a string.
# ...
# Enter a string:  sring
# String after removing duplicates:
# sring
