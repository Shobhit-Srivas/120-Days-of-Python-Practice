# %% [markdown]
# # Problem 91: Create a script to convert binary string to decimal.

# %%
print("=" * 60)
print("Q21. Create a script to convert binary string to decimal.")
print("=" * 60)

binary = input("Enter a binary number: ")

decimal = int(binary, 2)

print("\nDecimal Value:", decimal)
# Out:
# ...
# Q21. Create a script to convert binary string to decimal.
# ...
# Enter a binary number:  1100
# Decimal Value: 12
