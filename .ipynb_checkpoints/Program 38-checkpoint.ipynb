# %% [markdown]
# # Problem 38: Write a program to merge two dictonaries.

# %%
print("=" * 60)
print("Q8. Write a program to merge two dictionaries.")
print("=" * 60)

dict1 = {"a": 10, "b": 20}
dict2 = {"c": 30, "d": 40}

merged = {**dict1, **dict2}

print("\nMerged Dictionary:")
print(merged)
# Out:
# ...
# Q8. Write a program to merge two dictionaries.
# ...
#
# Merged Dictionary:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}
