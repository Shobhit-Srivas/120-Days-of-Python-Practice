# %% [markdown]
# # Problem 9: Write a Python script to reverse a given string.

# %%
text = input("Enter a string: ")

print("Reversed string:", text[::-1])
# Out:
# Enter a string:  thei
# Reversed string: ieht
