# %% [markdown]
# # Problem 12: Create a number guessing game.

# %%
import random

print("=" * 60)
print("Q12. Create a number guessing game.")
print("=" * 60)

number = random.randint(1, 100)

while True:
    guess = int(input("Guess a number between 1 and 100: "))

    if guess < number:
        print("Too low! Try again.")
    elif guess > number:
        print("Too high! Try again.")
    else:
        print("Congratulations! You guessed the correct number.")
        break
# Out:
# ============================================================
# Q12. Create a number guessing game.
# ============================================================
# Guess a number between 1 and 100:  12
# Too low! Try again.
