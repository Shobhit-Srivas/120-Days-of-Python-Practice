# %% [markdown]
# # Problem 53: Create a nested dictonary to represent student records.

# %%
print("=" * 60)
print("Q23. Create a nested dictionary to represent student records.")
print("=" * 60)

students = {
    "Student1": {
        "Name": "Rahul",
        "Age": 20,
        "Marks": 85
    },
    "Student2": {
        "Name": "Aman",
        "Age": 21,
        "Marks": 90
    }
}

print("\nStudent Records:")
print(students)
# Out:
# ...
# Q23. Create a nested dictionary to represent student records.
# ...
#
# Student Records:
# {'Student1': {'Name': 'Rahul', 'Age': 20, 'Marks': 85}, 'Student2': {'Name': 'Aman', 'Age': 21, 'Marks': 90}}
