# %% [markdown]
# # Problem 85: Write a Python program to merge two dictionaries into one.

# %%
print("=" * 60)
print("Q15. Write a Python program to merge two dictionaries into one.")
print("=" * 60)

dict1 = {"a": 10, "b": 20}
dict2 = {"c": 30, "d": 40}

merged = {**dict1, **dict2}

print("\nMerged Dictionary:")
print(merged)
# Out:
# ...
# Q15. Write a Python program to merge two dictionaries into one.
# ...
#
# Merged Dictionary:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}
