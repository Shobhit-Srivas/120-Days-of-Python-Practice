# %% [markdown]
# # Problem 95: Write a function that returns a new string made of every third character of the original string

# %%
print("=" * 60)
print("Q25. Write a function that returns a new string made of every third character of the original string.")
print("=" * 60)

text = input("Enter a string: ")

result = text[::3]

print("\nResulting String:")
print(result)
# Out:
# ...
# Q25. Write a function that returns a new string made of every third character of the original string.
# ...
# Enter a string:  that is a ball
# Resulting String:
# tts l
