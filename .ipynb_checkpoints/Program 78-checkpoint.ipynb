# %% [markdown]
# # Problem 78: Write a Python script to sort words in a sentence alphabetically

# %%
print("=" * 60)
print("Q8. Write a Python script to sort words in a sentence alphabetically.")
print("=" * 60)

sentence = input("Enter a sentence: ")

words = sentence.split()

words.sort()

print("\nWords in Alphabetical Order:")
print(words)
# Out:
# ...
# Q8. Write a Python script to sort words in a sentence alphabetically.
# ...
# Enter a sentence:  this is a pe
# Words in Alphabetical Order:
# ['a', 'is', 'pe', 'this']
