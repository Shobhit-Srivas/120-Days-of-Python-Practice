# %% [markdown]
# # Problem 40: Create a dictonary of squares of numbers from 1 to 10.

# %%
print("=" * 60)
print("Q10. Create a dictionary of squares of numbers from 1 to 10.")
print("=" * 60)

squares = {i: i ** 2 for i in range(1, 11)}

print("\nDictionary of Squares:")
print(squares)
# Out:
# ...
# Q10. Create a dictionary of squares of numbers from 1 to 10.
# ...
#
# Dictionary of Squares:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
