# %% [markdown]
# # Problem 21:  Write a program to count the number of digits in an integer.

# %%
print("=" * 60)
print("Q21. Write a program to count the number of digits in an integer.")
print("=" * 60)

num = input("Enter an integer: ")

print("\nNumber of digits:", len(num.lstrip("-")))
# Out:
# ...
# Q21. Write a program to count the number of digits in an integer.
# ...
# Enter an integer:  2
# Number of digits: 1
