# %% [markdown]
# # Problem 25: Write a program to display the ASCII value of a character.

# %%
print("=" * 60)
print("Q25. Write a program to display the ASCII value of a character.")
print("=" * 60)

ch = input("Enter a character: ")

print("\nASCII value of", ch, "is:", ord(ch))
# Out:
# ...
# Q25. Write a program to display the ASCII value of a character.
# ...
# Enter a character:  A
# ASCII value of A is: 65
