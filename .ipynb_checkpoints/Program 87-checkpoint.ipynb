# %% [markdown]
# # Problem 87: Write a function that returns True if a string ends with a given suffix.

# %%
print("=" * 60)
print("Q17. Write a function that returns True if a string ends with a given suffix.")
print("=" * 60)

text = input("Enter a string: ")
suffix = input("Enter a suffix: ")

print("\nResult:", text.endswith(suffix))
# Out:
# ...
# Q17. Write a function that returns True if a string ends with a given suffix.
# ...
# Enter a string:  this is a
# Enter a suffix:  is
# Result: False
