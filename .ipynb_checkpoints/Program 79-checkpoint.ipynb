# %% [markdown]
# # Problem 79: Write a program to check if two strings are anagrams.

# %%
print("=" * 60)
print("Q9. Write a program to check if two strings are anagrams.")
print("=" * 60)

str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

if sorted(str1.lower()) == sorted(str2.lower()):
    print("\nThe strings are Anagrams.")
else:
    print("\nThe strings are not Anagrams.")
# Out:
# ============================================================
# Q9. Write a program to check if two strings are anagrams.
# ============================================================
# Enter first string:  this
# Enter second string:  is
# The strings are not Anagrams.
