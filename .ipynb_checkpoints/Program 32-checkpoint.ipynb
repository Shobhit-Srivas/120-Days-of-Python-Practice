# %% [markdown]
# # Problem 32:  Create a list and find the sum of all its elements.

# %%
print("=" * 60)
print("Q2. Create a list and find the sum of all its elements.")
print("=" * 60)

numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

print("\nSum of all elements:", sum(numbers))
# Out:
# ...
# Q2. Create a list and find the sum of all its elements.
# ...
# Enter numbers separated by spaces:  1 2
# Sum of all elements: 3
