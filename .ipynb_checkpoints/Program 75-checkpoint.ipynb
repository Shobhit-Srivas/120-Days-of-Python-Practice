# %% [markdown]
# # Problem 75:  Create a program to fnd the longest word in a sentence.

# %%
print("=" * 60)
print("Q5. Create a program to find the longest word in a sentence.")
print("=" * 60)

sentence = input("Enter a sentence: ")

words = sentence.split()

longest = max(words, key=len)

print("\nLongest Word:", longest)
# Out:
# ...
# Q5. Create a program to find the longest word in a sentence.
# ...
# Enter a sentence:  this is a pen
# Longest Word: this
